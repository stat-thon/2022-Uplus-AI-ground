# %% [markdown]
# ## 데이터 전처리
# ### 기본 설정

# %%
# 패키지 로드
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from collections import defaultdict
import os, random

from scipy import sparse
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.nn.init import normal_
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

import plotnine
from plotnine import *

import pickle

# %%
# 경로 설정
data_path = './data'
saved_path = './code/saved'
output_path = './code/submission'

# %% [markdown]
# ### 데이터 불러오기
# - history_data : 시청 시작 데이터
# - profile_data : 프로필 정보
# - meta_data : 콘텐츠 일반 메타 정보

# %%
# 데이터 불러오기 
history_df = pd.read_csv(os.path.join(data_path, 'history_data.csv'), encoding='utf-8')
search_df = pd.read_csv(os.path.join(data_path, 'search_data.csv'), encoding='utf-8')
profile_df = pd.read_csv(os.path.join(data_path, 'profile_data.csv'), encoding='utf-8')
meta_df = pd.read_csv(os.path.join(data_path, 'meta_data.csv'), encoding='utf-8')
we_df = pd.read_csv(os.path.join(data_path, 'watch_e_data.csv'), encoding='utf-8')
buy_df = pd.read_csv(os.path.join(data_path, 'buy_data.csv'), encoding='utf-8')

# %% [markdown]
# ## 앨범 관심 시청별 최다 키워드

# %%
### 키워드 별 인원을 나타내기위해 하나로 모으기
keyword1 = profile_df[['profile_id', 'pr_interest_keyword_cd_1', 'ch_interest_keyword_cd_1']]
keyword2 = profile_df[['profile_id', 'pr_interest_keyword_cd_2', 'ch_interest_keyword_cd_2']]
keyword3 = profile_df[['profile_id', 'pr_interest_keyword_cd_3', 'ch_interest_keyword_cd_3']]

# %%
### cbind하기 전 이름 통일
keyword1.columns = ["profile_id","pr_int","ch_int"]
keyword2.columns = ["profile_id","pr_int","ch_int"]
keyword3.columns = ["profile_id","pr_int","ch_int"]

# %%
### 위/아래로 합치기 - 행 기준
keyword = pd.concat([keyword1, keyword2, keyword3], axis = 0).dropna(axis=0)

# %%
keyword
# Out:
#       profile_id pr_int ch_int
# 0              3    P02    K01
# 1              5    P07    K05
# 2              7    P05    K06
# 3             12    P03    K09
# 4             16    P03    K01
# ...          ...    ...    ...
# 8305       33019    P01    K09
# 8307       33023    P07    K05
# 8308       33026    P08    K06
# 8309       33027    P06    K05
# 8310       33032    P07    K09
#
# [20283 rows x 3 columns]

# %%
### 행동 패턴 데이터
data = pd.read_csv("behavior.csv")
### 모든 데이터의 시작은 1로
data['start'] = 1
### 종료 1인 경우 양수 0인 경우 음수
data['sign'] = 1
data['sign'][data['yes_watch'] == 0] = -1
data['yes_watch'] = data['yes_watch'] - 0.5
data['score'] = (2.5 + data['yes_watch'] + (data['buy'] + data['search'])*data['sign'])/15

# %%
data
# Out:
#         profile_id  album_id  yes_watch  payment  buy  search  start  sign  \
# 0                3        15        0.5      0.0  0.0     0.0      1     1
# 1                3        16        0.5      0.0  0.0     0.0      1     1
# 2                3        16        0.5      0.0  0.0     0.0      1     1
# 3                3        17        0.5      0.0  0.0     0.0      1     1
# 4                3        18        0.5      0.0  0.0     0.0      1     1
# ...            ...       ...        ...      ...  ...     ...    ...   ...
# 752742       33032       381        0.5      0.0  0.0     0.0      1     1
# 752743       33032       375        0.5      0.0  0.0     0.0      1     1
# 752744       33032       375        0.5      0.0  0.0     0.0      1     1
# 752745       33032       125        0.5      0.0  0.0     0.0      1     1
# 752746       33032       125        0.5      0.0  0.0     0.0      1     1
#
#         score
# 0         0.2
# 1         0.2
# 2         0.2
# 3         0.2
# 4         0.2
# ...       ...
# 752742    0.2
# 752743    0.2
# 752744    0.2
# 752745    0.2
# 752746    0.2
#
# [752747 rows x 9 columns]

# %%
data.drop_duplicates(['profile_id', 'album_id'])
# Out:
#         profile_id  album_id  yes_watch  payment  buy  search  start  sign  \
# 0                3        15        0.5      0.0  0.0     0.0      1     1
# 1                3        16        0.5      0.0  0.0     0.0      1     1
# 3                3        17        0.5      0.0  0.0     0.0      1     1
# 4                3        18        0.5      0.0  0.0     0.0      1     1
# 6                3        19        0.5      0.0  0.0     0.0      1     1
# ...            ...       ...        ...      ...  ...     ...    ...   ...
# 752732       33032       190       -0.5      0.0  0.0     0.0      1    -1
# 752733       33032       381        0.5      0.0  0.0     0.0      1     1
# 752739       33032       327       -0.5      0.0  0.0     0.0      1    -1
# 752740       33032      1725       -0.5      0.0  0.0     0.0      1    -1
# 752743       33032       375        0.5      0.0  0.0     0.0      1     1
#
#            score
# 0       0.200000
# 1       0.200000
# 3       0.200000
# 4       0.200000
# 6       0.200000
# ...          ...
# 752732  0.133333
# 752733  0.200000
# 752739  0.133333
# 752740  0.133333
# 752743  0.200000
#
# [328432 rows x 9 columns]

# %%
new = we_df[['profile_id', 'album_id']].drop_duplicates(['profile_id', 'album_id'])

# %%
new
# Out:
#         profile_id  album_id
# 0                3        15
# 1                3        16
# 2                3        17
# 3                3        18
# 4                3        19
# ...            ...       ...
# 892777       33032         0
# 892778       33032      1725
# 892780       33032      3128
# 892782       33032      3625
# 892783       33032       375
#
# [347982 rows x 2 columns]

# %%
new_meta = meta_df.drop_duplicates('album_id')[['album_id', 'genre_mid']]

# %%
new_k = pd.merge(new, new_meta, on = 'album_id', how = 'left')

# %%
new_k
# Out:
#         profile_id  album_id genre_mid
# 0                3        15      노래율동
# 1                3        16      노래율동
# 2                3        17      노래율동
# 3                3        18      노래율동
# 4                3        19      노래율동
# ...            ...       ...       ...
# 347977       33032         0       외국어
# 347978       33032      1725      노래율동
# 347979       33032      3128       외국어
# 347980       33032      3625      노래율동
# 347981       33032       375      놀이교실
#
# [347982 rows x 3 columns]

# %%
kk = pd.merge(new_k, keyword, on = 'profile_id', how = 'inner')

# %%
kk
# Out:
#         profile_id  album_id genre_mid pr_int ch_int
# 0                3        15      노래율동    P02    K01
# 1                3        15      노래율동    P04    K03
# 2                3        15      노래율동    P07    K04
# 3                3        16      노래율동    P02    K01
# 4                3        16      노래율동    P04    K03
# ...            ...       ...       ...    ...    ...
# 845738       33032      3625      노래율동    P05    K05
# 845739       33032      3625      노래율동    P07    K09
# 845740       33032       375      놀이교실    P03    K01
# 845741       33032       375      놀이교실    P05    K05
# 845742       33032       375      놀이교실    P07    K09
#
# [845743 rows x 5 columns]

# %%
k = pd.merge(new, keyword, on = 'profile_id', how = 'inner')

# %%
k
# Out:
#         profile_id  album_id pr_int ch_int
# 0                3        15    P02    K01
# 1                3        15    P04    K03
# 2                3        15    P07    K04
# 3                3        16    P02    K01
# 4                3        16    P04    K03
# ...            ...       ...    ...    ...
# 845738       33032      3625    P05    K05
# 845739       33032      3625    P07    K09
# 845740       33032       375    P03    K01
# 845741       33032       375    P05    K05
# 845742       33032       375    P07    K09
#
# [845743 rows x 4 columns]

# %%
### 키워드 별 인원수 세기
kpcount = keyword.groupby('pr_int')['profile_id'].count()
kccount = keyword.groupby('ch_int')['profile_id'].count()

# %%
kpcount
# Out:
# pr_int
# P01    2102
# P02    3112
# P03    2881
# P04    1773
# P05    1837
# P06    3780
# P07    3238
# P08    1560
# Name: profile_id, dtype: int64

# %%
### 부모, 자녀 키워드 앨범, 키워드별 각각 인원수 세기
kk2 = pd.DataFrame(kk.groupby(['genre_mid','pr_int']).count()).reset_index()
kk3 = pd.DataFrame(kk.groupby(['genre_mid','ch_int']).count()).reset_index()

# %%
kk2
# Out:
#     genre_mid pr_int  profile_id  album_id  ch_int
# 0         MCN    P01         160       160     160
# 1         MCN    P02          84        84      84
# 2         MCN    P03         115       115     115
# 3         MCN    P04          50        50      50
# 4         MCN    P05          57        57      57
# ..        ...    ...         ...       ...     ...
# 205        한자    P02           2         2       2
# 206        한자    P03           3         3       3
# 207        한자    P06           1         1       1
# 208        한자    P07           2         2       2
# 209        한자    P08           1         1       1
#
# [210 rows x 5 columns]

# %%
### 키워드를 열로 옮기기
par_with_genre_cnt = kk2.pivot(
    index = 'genre_mid',
    columns = 'pr_int',
    values = 'profile_id'
)

chi_with_genre_cnt = kk3.pivot(
    index = 'genre_mid',
    columns = 'ch_int',
    values = 'profile_id'
)

### 없는값은 0으로 채우기
### 앨범 별 키워드 인원 
par_with_genre_cnt = par_with_genre_cnt.reset_index().fillna(0)
chi_with_genre_cnt = chi_with_genre_cnt.reset_index().fillna(0)

# %%
kpcount
# Out:
# pr_int
# P01    2102
# P02    3112
# P03    2881
# P04    1773
# P05    1837
# P06    3780
# P07    3238
# P08    1560
# Name: profile_id, dtype: int64

# %%
par_with_genre_cnt
# Out:
# pr_int genre_mid       P01        P02        P03        P04        P05  \
# 0            MCN  0.076118   0.026992   0.039917   0.028201   0.031029
# 1           TV만화  8.976689  11.637853  10.658799  13.338973  13.187262
# 2         극장판 애니  0.016651   0.024100   0.022909   0.025945   0.023408
# 3          노래 율동  0.111323   0.197301   0.197501   0.213762   0.255308
# 4           노래율동  6.609420  15.146208  13.665741  17.170333  17.504627
# 5           놀이교실  3.694101   3.394602   3.992711   4.219402   3.862275
# 6          다큐멘터리  0.028069   0.025064   0.033322   0.016356   0.015787
# 7           독서동화  0.103711   0.138817   0.124262   0.142696   0.091998
# 8            드라마  0.050904   0.025064   0.032975   0.033841   0.036473
# 9           수학과학  0.039010   0.032134   0.035751   0.021433   0.027763
# 10           시리즈  0.584206   0.471080   0.437348   0.719120   0.649973
# 11          시사교양  0.005233   0.002571   0.002083   0.000000   0.000544
# 12            애니  0.449572   0.465938   0.498438   0.606317   0.639630
# 13         액션/모험  0.390580   0.336440   0.333218   0.418500   0.416440
# 14         어린이방송  0.197907   0.089974   0.118709   0.120135   0.167120
# 15         역사/문화  0.019981   0.019280   0.020826   0.019741   0.015787
# 16          연예오락  0.000000   0.000321   0.000000   0.000000   0.000544
# 17            예능  0.218363   0.118895   0.144741   0.128596   0.108329
# 18            예술  0.000000   0.000000   0.000694   0.000000   0.000544
# 19           외국어  2.738820   2.380784   2.511628   2.416808   2.090909
# 20          유아애니  0.052331   0.040810   0.048594   0.054146   0.040827
# 21          육아정보  0.031399   0.028920   0.050330   0.046249   0.066957
# 22          창의학습  0.201713   0.143959   0.147171   0.174845   0.151334
# 23             책  9.972407   8.472044   7.952794   7.485054   5.589548
# 24          체육안전  0.009039   0.000964   0.003818   0.006204   0.007621
# 25           코미디  0.059467   0.069409   0.083999   0.114495   0.100163
# 26            한글  0.039962   0.034062   0.039917   0.022561   0.025585
# 27            한자  0.000000   0.000643   0.001041   0.000000   0.000000
#
# pr_int        P06        P07        P08
# 0        0.033862   0.028104   0.038462
# 1       10.644444  11.032119   8.969872
# 2        0.018519   0.019148   0.012821
# 3        0.202381   0.194873   0.162179
# 4       15.066931  14.109944   7.364103
# 5        3.672751   3.901174   3.941026
# 6        0.023016   0.026868   0.028205
# 7        0.129365   0.160593   0.125641
# 8        0.043122   0.037678   0.050000
# 9        0.024603   0.048796   0.076282
# 10       0.387302   0.525942   0.466667
# 11       0.002646   0.002471   0.001923
# 12       0.500794   0.475911   0.405128
# 13       0.282011   0.372143   0.337821
# 14       0.115079   0.109944   0.194872
# 15       0.016402   0.015442   0.014103
# 16       0.000265   0.000000   0.000000
# 17       0.156349   0.146695   0.234615
# 18       0.000265   0.000309   0.000641
# 19       2.353439   2.891909   2.953205
# 20       0.042857   0.035207   0.028205
# 21       0.044709   0.054355   0.043590
# 22       0.189683   0.169240   0.226923
# 23       7.316138   8.530574  10.410897
# 24       0.000000   0.000000   0.005128
# 25       0.058995   0.090179   0.070513
# 26       0.028042   0.048487   0.072436
# 27       0.000265   0.000618   0.000641

# %%
### 선택 인원수 별로 나누어줌
for i in range(8):
    par_with_genre_cnt.iloc[:,i+1] = par_with_genre_cnt.iloc[:,i+1]/kpcount[i]
    
for j in range(9):
    chi_with_genre_cnt.iloc[:,j+1] = chi_with_genre_cnt.iloc[:,j+1]/kccount[j]

# %%
### 다시 melt
par_with_genre_melt = par_with_genre_cnt.melt(
    id_vars = "genre_mid",
    value_vars = ['P01','P02','P03','P04','P05','P06','P07','P08'],
    value_name = 'viewpersel',
    var_name = "pr_int"
)

chi_with_genre_melt = chi_with_genre_cnt.melt(
    id_vars = "genre_mid",
    value_vars = ['K01','K02','K03','K04','K05','K06','K07','K08','K09'],
    value_name = 'viewpersel',
    var_name = "ch_int"
)

# %%
par_with_genre_melt
# Out:
#     genre_mid pr_int  viewpersel
# 0         MCN    P01    0.076118
# 1        TV만화    P01    8.976689
# 2      극장판 애니    P01    0.016651
# 3       노래 율동    P01    0.111323
# 4        노래율동    P01    6.609420
# ..        ...    ...         ...
# 219         책    P08   10.410897
# 220      체육안전    P08    0.005128
# 221       코미디    P08    0.070513
# 222        한글    P08    0.072436
# 223        한자    P08    0.000641
#
# [224 rows x 3 columns]

# %%
### 각 앨범별 최대값과 그에 해당하는 선택 키워드
par_with_genre_max = par_with_genre_melt.loc[par_with_genre_melt.groupby(['genre_mid'])['viewpersel'].idxmax()]
chi_with_genre_max = chi_with_genre_melt.loc[chi_with_genre_melt.groupby(['genre_mid'])['viewpersel'].idxmax()]

# %%
pr_genre_dict = par_with_genre_max[['genre_mid', 'pr_int']].set_index('genre_mid').to_dict()
ch_genre_dict = chi_with_genre_max[['genre_mid', 'ch_int']].set_index('genre_mid').to_dict()

# %%
pr_genre_dict
# Out:
# {'pr_int': {'MCN': 'P01',
#   'TV만화': 'P04',
#   '극장판 애니': 'P04',
#   '노래 율동': 'P05',
#   '노래율동': 'P05',
#   '놀이교실': 'P04',
#   '다큐멘터리': 'P03',
#   '독서동화': 'P07',
#   '드라마': 'P01',
#   '수학과학': 'P08',
#   '시리즈': 'P04',
#   '시사교양': 'P01',
#   '애니': 'P05',
#   '액션/모험': 'P04',
#   '어린이방송': 'P01',
#   '역사/문화': 'P03',
#   '연예오락': 'P05',
#   '예능': 'P08',
#   '예술': 'P03',
#   '외국어': 'P08',
#   '유아애니': 'P04',
#   '육아정보': 'P05',
#   '창의학습': 'P08',
#   '책': 'P08',
#   '체육안전': 'P01',
#   '코미디': 'P04',
#   '한글': 'P08',
#   '한자': 'P03'}}

# %%
ch_genre_dict['ch_int']['TV만화']
# Out:
# 'K08'

# %% [markdown]
# ### 장르 결합

# %%
### 부모, 자녀 키워드 앨범, 키워드별 각각 인원수 세기
k2 = pd.DataFrame(k.groupby(['album_id','pr_int']).count()).reset_index()
k3 = pd.DataFrame(k.groupby(['album_id','ch_int']).count()).reset_index()

# %%
### 키워드를 열로 옮기기
par_cnt = k2.pivot(
    index = 'album_id',
    columns = 'pr_int',
    values = 'profile_id'
)

chi_cnt = k3.pivot(
    index = 'album_id',
    columns = 'ch_int',
    values = 'profile_id'
)

# %%
### 없는값은 0으로 채우기
### 앨범 별 키워드 인원 
par_cnt = par_cnt.reset_index().fillna(0)
chi_cnt = chi_cnt.reset_index().fillna(0)

# %%
### 선택 인원수 별로 나누어줌
for i in range(8):
    par_cnt.iloc[:,i+1] = par_cnt.iloc[:,i+1]/kpcount[i]
    
for j in range(9):
    chi_cnt.iloc[:,j+1] = chi_cnt.iloc[:,j+1]/kccount[j]

# %%
par_cnt
# Out:
# pr_int  album_id       P01       P02       P03       P04       P05       P06  \
# 0              0  0.077545  0.090296  0.093023  0.089114  0.087099  0.097354
# 1              1  0.011893  0.018316  0.017355  0.018613  0.016875  0.018519
# 2              2  0.011893  0.014781  0.017008  0.012972  0.013609  0.016931
# 3              3  0.014272  0.012532  0.014578  0.015792  0.018508  0.010847
# 4              4  0.008563  0.017031  0.017008  0.024253  0.018508  0.014286
# ...          ...       ...       ...       ...       ...       ...       ...
# 20356      25912  0.000476  0.000000  0.000000  0.000000  0.000000  0.000000
# 20357      25913  0.000476  0.000000  0.000000  0.000000  0.000000  0.000000
# 20358      25914  0.000476  0.000000  0.000000  0.000000  0.000000  0.000000
# 20359      25915  0.000476  0.000000  0.000000  0.000000  0.000000  0.000000
# 20360      25916  0.000476  0.000000  0.000000  0.000000  0.000000  0.000000
#
# pr_int       P07       P08
# 0       0.106547  0.094231
# 1       0.017603  0.013462
# 2       0.016986  0.016026
# 3       0.016677  0.010897
# 4       0.016059  0.014744
# ...          ...       ...
# 20356   0.000000  0.000000
# 20357   0.000000  0.000000
# 20358   0.000000  0.000000
# 20359   0.000000  0.000000
# 20360   0.000000  0.000000
#
# [20361 rows x 9 columns]

# %%
### 다시 melt
par_melt = par_cnt.melt(
    id_vars = "album_id",
    value_vars = ['P01','P02','P03','P04','P05','P06','P07','P08'],
    value_name = 'viewpersel',
    var_name = "pr_int"
)

chi_melt = chi_cnt.melt(
    id_vars = "album_id",
    value_vars = ['K01','K02','K03','K04','K05','K06','K07','K08','K09'],
    value_name = 'viewpersel',
    var_name = "ch_int"
)

# %%
par_melt
# Out:
#         album_id pr_int  viewpersel
# 0              0    P01    0.077545
# 1              1    P01    0.011893
# 2              2    P01    0.011893
# 3              3    P01    0.014272
# 4              4    P01    0.008563
# ...          ...    ...         ...
# 162883     25912    P08    0.000000
# 162884     25913    P08    0.000000
# 162885     25914    P08    0.000000
# 162886     25915    P08    0.000000
# 162887     25916    P08    0.000000
#
# [162888 rows x 3 columns]

# %%
### 각 앨범별 최대값과 그에 해당하는 선택 키워드
par_max = par_melt.loc[par_melt.groupby(['album_id'])['viewpersel'].idxmax()]
chi_max = chi_melt.loc[chi_melt.groupby(['album_id'])['viewpersel'].idxmax()]

# %% [markdown]
# ## 장르와 융합

# %%
### 중장르 뽑기
genre = meta_df[['album_id', 'genre_mid', 'sub_title']]

# %%
genre = genre.drop_duplicates('album_id')

# %%
genre
# Out:
#        album_id genre_mid   sub_title
# 0           749      TV만화    꼬마버스 타요1
# 1           750      TV만화    꼬마버스 타요1
# 2          2131      TV만화    꼬마버스 타요1
# 3          2625      TV만화    꼬마버스 타요1
# 4          2594      TV만화    꼬마버스 타요1
# ...         ...       ...         ...
# 42596     39872      놀이교실  로티프렌즈 미술놀이
# 42597     39873      놀이교실  로티프렌즈 미술놀이
# 42598     39874      놀이교실  로티프렌즈 미술놀이
# 42599      4779         책        4-5세
# 42601     11629      노래율동  베이비 타요 동요2
#
# [39875 rows x 3 columns]

# %%
meta_df.album_id.nunique()
# Out:
# 39875

# %%
par_fu.album_id.nunique()
# Out:
# 20361

# %%
me

# %%
chi_fu.album_id.nunique()
# Out:
# 20361

# %%
genre
# Out:
#        album_id genre_mid   sub_title
# 0           749      TV만화    꼬마버스 타요1
# 1           750      TV만화    꼬마버스 타요1
# 2          2131      TV만화    꼬마버스 타요1
# 3          2625      TV만화    꼬마버스 타요1
# 4          2594      TV만화    꼬마버스 타요1
# ...         ...       ...         ...
# 42596     39872      놀이교실  로티프렌즈 미술놀이
# 42597     39873      놀이교실  로티프렌즈 미술놀이
# 42598     39874      놀이교실  로티프렌즈 미술놀이
# 42599      4779         책        4-5세
# 42601     11629      노래율동  베이비 타요 동요2
#
# [39875 rows x 3 columns]

# %%
### 부모, 자녀 각 키워드랑 융합
par_with_genre_fu = pd.merge(genre, par_with_genre_max[['genre_mid','pr_int']], on = 'genre_mid')
chi_with_genre_fu = pd.merge(genre, chi_with_genre_max[['genre_mid','ch_int']], on = 'genre_mid')

# %%
par_with_genre_fu
# Out:
#        album_id genre_mid            sub_title pr_int
# 0           749      TV만화             꼬마버스 타요1    P04
# 1           750      TV만화             꼬마버스 타요1    P04
# 2          2131      TV만화             꼬마버스 타요1    P04
# 3          2625      TV만화             꼬마버스 타요1    P04
# 4          2594      TV만화             꼬마버스 타요1    P04
# ...         ...       ...                  ...    ...
# 39850      6302        한글  EBS 초등 만점왕 - 국어 2-1    P08
# 39851      6303        한글  EBS 초등 만점왕 - 국어 2-1    P08
# 39852      6309        한글  EBS 초등 만점왕 - 국어 2-1    P08
# 39853      6310        한글  EBS 초등 만점왕 - 국어 2-1    P08
# 39854      8264        한글  EBS 초등 만점왕 - 국어 1-1    P08
#
# [39855 rows x 4 columns]

# %%
chi_with_genre_fu
# Out:
#        album_id genre_mid            sub_title ch_int
# 0           749      TV만화             꼬마버스 타요1    K08
# 1           750      TV만화             꼬마버스 타요1    K08
# 2          2131      TV만화             꼬마버스 타요1    K08
# 3          2625      TV만화             꼬마버스 타요1    K08
# 4          2594      TV만화             꼬마버스 타요1    K08
# ...         ...       ...                  ...    ...
# 39850      6302        한글  EBS 초등 만점왕 - 국어 2-1    K05
# 39851      6303        한글  EBS 초등 만점왕 - 국어 2-1    K05
# 39852      6309        한글  EBS 초등 만점왕 - 국어 2-1    K05
# 39853      6310        한글  EBS 초등 만점왕 - 국어 2-1    K05
# 39854      8264        한글  EBS 초등 만점왕 - 국어 1-1    K05
#
# [39855 rows x 4 columns]

# %%
### 부모, 자녀 각 키워드랑 융합
par_fu = pd.merge(genre, par_max[['album_id','pr_int']],left_on='album_id', right_on='album_id', how='right')
chi_fu = pd.merge(genre, chi_max[['album_id','ch_int']],left_on='album_id', right_on='album_id', how='right')

# %%
par_fu
# Out:
#        album_id genre_mid              sub_title pr_int
# 0             0       외국어               디즈니 프린세스    P07
# 1             1       외국어               베베 뮤직스토리    P04
# 2             2       외국어               베베 뮤직스토리    P03
# 3             3       외국어                     픽사    P05
# 4             4      TV만화              출동! 슈퍼윙스1    P04
# ...         ...       ...                    ...    ...
# 20356     25912      독서동화         주니토니 NEW 동화뮤지컬    P01
# 20357     25913      노래율동             퓨처북 공룡 동요2    P01
# 20358     25914      노래율동             퓨처북 공룡 동요2    P01
# 20359     25915      노래율동             퓨처북 공룡 동요2    P01
# 20360     25916      노래율동  주니토니 어쩌다 암기왕 두잇두잇 언어왕    P01
#
# [20361 rows x 4 columns]

# %%
par_fu.groupby(['sub_title']).value_counts().reset_index()
# Out:
#              sub_title  album_id genre_mid pr_int  0
# 0      100분! 뽀요 인기 메들리     23104      노래율동    P03  1
# 1          10월 세계 여러나라      6596      놀이교실    P04  1
# 2           11월 지구와 우주      7071      놀이교실    P08  1
# 3               12월 겨울      2633      놀이교실    P08  1
# 4              1월 생활도구      3806      놀이교실    P07  1
# ...                ...       ...       ...    ... ..
# 20356           히어로 써클     22399      TV만화    P04  1
# 20357           히어로 써클     22397      TV만화    P04  1
# 20358           히어로 써클     21564      TV만화    P04  1
# 20359           히어로 써클     16177      TV만화    P04  1
# 20360           히어로 써클     25175      TV만화    P04  1
#
# [20361 rows x 5 columns]

# %%
meta_sub_title = meta_df.sub_title.value_counts().reset_index()
meta_sub_title.columns = ['sub_title', 'count']

# %%
# sub_title 하나인 것 -> 164개
meta_sub_title.loc[meta_sub_title['count'] == 1]

#sub_title 두개인 것 -> 99개
meta_sub_title.loc[meta_sub_title['count'] == 2]

#sub_title 3개인 것 -> 91개
meta_sub_title.loc[meta_sub_title['count'] == 1]
# Out:
#                                     sub_title  count
# 2209  오늘의 영어 3주차 알파벳 "wh, th, ck" / Community      1
# 2210                         Jesse의 플레이 키친(하)      1
# 2211  오늘의 영어 13주차 파닉스 "ea (I, e)" / Education      1
# 2212                                 도전 에코 키즈      1
# 2213   오늘의 영어 9주차 알파벳 "ar, er" / Special Days      1
# ...                                       ...    ...
# 2368                                   12월 겨울      1
# 2369                                  1월 생활도구      1
# 2370                                2월 자연과 동물      1
# 2371                              3월 새로움이 많아요      1
# 2372                             디즈니 프린세스 더보기      1
#
# [164 rows x 2 columns]

# %%
meta_genre = meta_df.drop_duplicates('album_id')[['album_id', 'genre_mid']]

# %%
meta_genre
# Out:
#        album_id genre_mid
# 0           749      TV만화
# 1           750      TV만화
# 2          2131      TV만화
# 3          2625      TV만화
# 4          2594      TV만화
# ...         ...       ...
# 42596     39872      놀이교실
# 42597     39873      놀이교실
# 42598     39874      놀이교실
# 42599      4779         책
# 42601     11629      노래율동
#
# [39875 rows x 2 columns]

# %%
pr_genre_dict['pr_int']
# Out:
# {'MCN': 'P01',
#  'TV만화': 'P04',
#  '극장판 애니': 'P04',
#  '노래 율동': 'P05',
#  '노래율동': 'P05',
#  '놀이교실': 'P04',
#  '다큐멘터리': 'P03',
#  '독서동화': 'P07',
#  '드라마': 'P01',
#  '수학과학': 'P08',
#  '시리즈': 'P04',
#  '시사교양': 'P01',
#  '애니': 'P05',
#  '액션/모험': 'P04',
#  '어린이방송': 'P01',
#  '역사/문화': 'P03',
#  '연예오락': 'P05',
#  '예능': 'P08',
#  '예술': 'P03',
#  '외국어': 'P08',
#  '유아애니': 'P04',
#  '육아정보': 'P05',
#  '창의학습': 'P08',
#  '책': 'P08',
#  '체육안전': 'P01',
#  '코미디': 'P04',
#  '한글': 'P08',
#  '한자': 'P03'}

# %%
meta_genre_with_keyowrd = pd.merge(meta_genre, par_with_genre_max[['genre_mid','pr_int']], on = 'genre_mid', how = 'left')

# %%
meta_genre_with_keyowrd
# Out:
#        album_id genre_mid pr_int
# 0           749      TV만화    P04
# 1           750      TV만화    P04
# 2          2131      TV만화    P04
# 3          2625      TV만화    P04
# 4          2594      TV만화    P04
# ...         ...       ...    ...
# 39870     39872      놀이교실    P04
# 39871     39873      놀이교실    P04
# 39872     39874      놀이교실    P04
# 39873      4779         책    P08
# 39874     11629      노래율동    P05
#
# [39875 rows x 3 columns]

# %%
h = meta_df.drop_duplicates('album_id')[['album_id', 'sub_title']]

# %%
h
# Out:
#        album_id   sub_title
# 0           749    꼬마버스 타요1
# 1           750    꼬마버스 타요1
# 2          2131    꼬마버스 타요1
# 3          2625    꼬마버스 타요1
# 4          2594    꼬마버스 타요1
# ...         ...         ...
# 42596     39872  로티프렌즈 미술놀이
# 42597     39873  로티프렌즈 미술놀이
# 42598     39874  로티프렌즈 미술놀이
# 42599      4779        4-5세
# 42601     11629  베이비 타요 동요2
#
# [39875 rows x 2 columns]

# %%
new_par_fu = pd.merge(h, par_max[['album_id','pr_int']],left_on='album_id', right_on='album_id', how='left')

# %%
new_par_fu
# Out:
#        album_id   sub_title pr_int
# 0           749    꼬마버스 타요1    P05
# 1           750    꼬마버스 타요1    P05
# 2          2131    꼬마버스 타요1    P05
# 3          2625    꼬마버스 타요1    P05
# 4          2594    꼬마버스 타요1    P05
# ...         ...         ...    ...
# 39870     39872  로티프렌즈 미술놀이    NaN
# 39871     39873  로티프렌즈 미술놀이    NaN
# 39872     39874  로티프렌즈 미술놀이    NaN
# 39873      4779        4-5세    NaN
# 39874     11629  베이비 타요 동요2    NaN
#
# [39875 rows x 3 columns]

# %%
ho = new_par_fu[['sub_title', 'pr_int']].value_counts().reset_index().sort_values('sub_title')

# %%
meta_subtitle_key_dict = dict()

temp = 'a'
MAX = 0
for i in ho.itertuples():
    if temp == i[1]:
        MAX = max(MAX, i[3])
        if MAX == i[3]:
            meta_subtitle_key_dict[i[1]] = i[2]
    else:
        temp = i[1]
        meta_subtitle_key_dict[i[1]] = i[2]

# %%
meta_subtitle_key_dict
# Out:
# {'100분! 뽀요 인기 메들리': 'P03',
#  '10월 세계 여러나라': 'P04',
#  '11월 지구와 우주': 'P08',
#  '12월 겨울': 'P08',
#  '1월 생활도구': 'P07',
#  '2월 자연과 동물': 'P04',
#  '3세이하': 'P02',
#  '3월 새로움이 많아요': 'P04',
#  '4-5세': 'P01',
#  '4남매쇼': 'P06',
#  '4월 봄': 'P04',
#  '5가지 뽀롱뽀롱 꿈 상담소': 'P02',
#  '5분 종이접기 한반도의 공룡편': 'P04',
#  '5월 몸짱 마음짱': 'P08',
#  '6-7세': 'P01',
#  '60분 뽀요 율동 메들리': 'P02',
#  '60초툰': 'P04',
#  '6월 우리동네': 'P04',
#  '7월 여름과 건강': 'P04',
#  '8-9세': 'P01',
#  '8월 교통기관': 'P04',
#  '9월 우리나라': 'P04',
#  'A Day with Little Monkey': 'P06',
#  'A New Baby Is Coming': 'P08',
#  'A Picnic Day': 'P08',
#  'A Super Halloween': 'P04',
#  'A Wish For Whales': 'P03',
#  'ABC Song': 'P08',
#  'Alligator Eats Candies': 'P08',
#  'Animals at the Zoo': 'P03',
#  'A~Z까지 알파벳 배우기': 'P08',
#  'Baby Bear`s New Friend': 'P07',
#  'Bath Time Fun': 'P08',
#  'Ben Bakes Cakes': 'P08',
#  'Ben Is Too Big': 'P08',
#  'Big Big Big Bread': 'P08',
#  'Big Bob Small Sam': 'P07',
#  'Brown Bear`s Birthday': 'P03',
#  'Butterflies Fly': 'P08',
#  'Cat and Rat Play Together': 'P08',
#  'Collin Goes to a Toilet': 'P03',
#  'Decorate a Chrismas Tree': 'P04',
#  'Detective Freddy`s Vacation': 'P04',
#  'Dora Dances in a festival': 'P08',
#  'EBS 스쿨랜드': 'P05',
#  'EBS 초등 만점왕 - 국어 1-1': 'P08',
#  'EBS 초등 만점왕 - 국어 1-2': 'P08',
#  'EBS 초등 만점왕 - 국어 2-1': 'P04',
#  'EBS 초등 만점왕 - 국어 2-2': 'P03',
#  'EBS 초등 만점왕 - 수학 1-1': 'P07',
#  'EBS 초등 만점왕 - 수학 1-2': 'P03',
#  'EBS 초등 만점왕 - 수학 2-1': 'P05',
#  'EBS 초등 만점왕 - 수학 2-2': 'P08',
#  'EBS 한반도의 공룡': 'P04',
#  'Elly`s Playtime': 'P04',
#  'Elmo`s World': 'P02',
#  'Five little Chameleons': 'P08',
#  'Go to Play Hide and Seek': 'P07',
#  'HEY 타요': 'P07',
#  'Help Mermaid': 'P04',
#  'Hen Makes a Nest': 'P01',
#  'Hi, Stars!': 'P04',
#  'Honk! Honk!': 'P04',
#  'How Does Rain Falls?': 'P04',
#  'I Am Short': 'P01',
#  'I Am leaving': 'P08',
#  'I Can Do It Myself': 'P08',
#  'I Can Help': 'P04',
#  'I Feel Happy': 'P08',
#  'I Feel Much Better': 'P01',
#  'I Like the way I Am': 'P04',
#  'I Love Kisses (chant)': 'P05',
#  'I Love My Family': 'P02',
#  'I Meet Animal Friends': 'P02',
#  'I Put on the Clothes': 'P01',
#  'I Really Like Sports Day': 'P04',
#  'I Want a Pet': 'P04',
#  'I Wash': 'P06',
#  'Jack and His Kitten': 'P01',
#  'Jesse의 플레이 키친(상)': 'P01',
#  'Joan Teaches Sammy Dancing': 'P04',
#  'Joan and Mimi Play the Piano': 'P04',
#  'Let`s Go Swimming': 'P03',
#  'Let`s Make a Zoo': 'P04',
#  'Let`s Swim in the Tub': 'P03',
#  'Little Hippo`s Color Day': 'P02',
#  'Little Princess': 'P08',
#  'Littler Spider`s New House': 'P03',
#  'Maddie in the Mud': 'P05',
#  'Magic Crayons': 'P04',
#  'Mimi Follows a Ball': 'P01',
#  'NEW 꼬꼬마 텔레토비2': 'P05',
#  'NEW 꼬꼬마 텔레토비3': 'P08',
#  'NEW 꼬꼬마 텔레토비4': 'P05',
#  'NEW 꼬꼬마 텔레토비5': 'P05',
#  'NEW 뽀롱뽀롱 뽀로로1': 'P05',
#  'NEW뽀로로와 노래해요1': 'P05',
#  'NEW뽀로로와 노래해요1(영어)': 'P05',
#  'NEW뽀로로와 노래해요2': 'P03',
#  'NEW뽀로로와 노래해요2(영어)': 'P05',
#  'Noises In the Night': 'P08',
#  'One, Two, Three, Four, Five': 'P04',
#  'Ox, Yak and Zebra Are Yawning': 'P03',
#  'Pig`s Happy Day': 'P01',
#  'Pororo Talk 1': 'P02',
#  'Pororo Talk 2': 'P02',
#  'Princess Pamela and the Polite Dragon': 'P08',
#  'Queen in the Rain': 'P02',
#  'Rainy Day Funny Day': 'P08',
#  'Ride and Stop': 'P06',
#  'STEP1': 'P01',
#  'STEP3': 'P04',
#  'SUPADUPA(슈파듀파)': 'P07',
#  'Salad with Nuts and Pears': 'P01',
#  'Sally Goes to Kindergarten': 'P04',
#  'Say Please and Thank you': 'P04',
#  'Seeds Grow': 'P08',
#  'Sesame Street ABC song': 'P07',
#  'Sharing is Good': 'P04',
#  'Shelby the Shy Shark': 'P08',
#  'Sleep Well, Tot': 'P01',
#  'Soft or Hard?': 'P02',
#  'Something for Santa': 'P08',
#  'Sweet Dreams': 'P01',
#  'TIKITAKA 티키타카': 'P05',
#  'The Moon Follows Me': 'P08',
#  'The Raindrop Concert': 'P04',
#  'The Short A Song #1': 'P06',
#  'The Short A Song #2': 'P02',
#  'The Short E Song #1': 'P01',
#  'The Short E Song #2': 'P01',
#  'The Waddle-Waddle Expedition': 'P04',
#  'The Wolf and Little Red': 'P01',
#  'Timmy Takes a Nap': 'P04',
#  'Toot, Toot, Penguin Train Goes': 'P04',
#  'VOOKS': 'P01',
#  'WHO-위인극장': 'P03',
#  'Way to Grandma`s': 'P08',
#  'We Eat Fruits': 'P03',
#  'We Invite You to Our Performance': 'P04',
#  'We Love Vehicles': 'P04',
#  'What Can I Ride?': 'P08',
#  'What Is Good for Your Health?': 'P04',
#  'When I Am Big': 'P08',
#  'Where Are You? Mrs, Four Season?': 'P08',
#  'Who Are You?': 'P08',
#  'Who Is Scary?': 'P03',
#  'Who Is This Paper Boat for?': 'P08',
#  'Whose House Is This?': 'P08',
#  'Wolf has a Very Nice Wagon': 'P04',
#  'Yummy Yummy Yum-Yum!': 'P02',
#  '[감기] I got a cold': 'P02',
#  '[대교전집]My First Reading': 'P03',
#  '[대교전집]My First Story': 'P04',
#  '[상단] 대교상상동화': 'P03',
#  '[상단] 신나는 노래율동': 'P03',
#  '[상단] 호랑이 해': 'P07',
#  '[상단]My First Story한글': 'P02',
#  '[상단]마마파파': 'P08',
#  '[상단]에그박사와 자연친구들': 'P08',
#  '[상단테마 영어1]': 'P04',
#  '[상단테마 캐릭터3]': 'P04',
#  "[신나는 영어 모아보자!]  Let's play together": 'P02',
#  '[신나는 영어 모아보자!]  My favorite color is green': 'P06',
#  '[신나는 영어 모아보자!]  We are going to the zoo': 'P02',
#  '[신나는 영어 모아보자!]  You are my best friend': 'P02',
#  '[우리말]리틀 드래곤 코코넛 Part2': 'P04',
#  '[우리말]마야의 모험': 'P07',
#  '[우리말]마야의 모험 2 Part1': 'P08',
#  '[우리말]마야의 모험 2 Part2': 'P04',
#  '[하단] 영어유치원 지면1': 'P01',
#  '[하단] 영어유치원 지면2': 'P07',
#  '{상단} 우아달': 'P03',
#  '감기는 너무해': 'P04',
#  '감기의 증상과 대처법': 'P07',
#  '감염 질환과 예방, 관리': 'P07',
#  '강아지는 내 친구': 'P07',
#  '강철소방대 파이어로보': 'P01',
#  '개구리야 안녕?': 'P03',
#  '개구쟁이 조이': 'P04',
#  '갤럭시 안전 프로젝트': 'P04',
#  '갤럭시 키즈1': 'P04',
#  '갤럭시 키즈2': 'P06',
#  '갤럭시 프로젝트': 'P01',
#  '건강을 지켜요(운동)': 'P05',
#  '고 버스터 러닝동요': 'P04',
#  '고 버스터 모험동요': 'P08',
#  '고고 공룡탐험': 'P05',
#  '고고다이노 공룡송1': 'P02',
#  '고고다이노 공룡송2': 'P03',
#  '고고다이노 공룡송3': 'P04',
#  '고고다이노 공룡탐험대1': 'P03',
#  '고고다이노 공룡탐험대2': 'P04',
#  '고고다이노 공룡탐험대3': 'P03',
#  '고고다이노 공룡탐험대4': 'P05',
#  '고고다이노 캐릭터송': 'P07',
#  '고민뿜뿜! 키즈상담소': 'P05',
#  '곤2': 'P08',
#  '곤충대탐험(상)': 'P01',
#  '곤충대탐험(하)': 'P03',
#  '공룡메카드 Part2': 'P08',
#  '공룡이 돌아왔다!': 'P05',
#  '공주님 겨울캠프': 'P01',
#  '공주님 여름캠프': 'P01',
#  '과학 애니메이션 WHY?': 'P04',
#  '과학교실': 'P02',
#  '구름빵1': 'P08',
#  '구름빵2': 'P03',
#  '구름빵3': 'P08',
#  '구조도구 (로이＆헬리)': 'P01',
#  '구조도구 (진＆마크＆버키)': 'P05',
#  '구조도구 (폴리＆엠버)': 'P05',
#  '국악동요 한글교실 좌충우돌 무지개 국악놀이터 동물 체조': 'P06',
#  '귀여운 친구, 동물': 'P05',
#  '그레이트북스 아이들나라 독점제공!': 'P01',
#  '극장판': 'P05',
#  '긴급상황! 우리 몸 X파일': 'P08',
#  '김치는 대단해': 'P04',
#  '깨미': 'P04',
#  '깨미랑 부카채카1': 'P01',
#  '깨미랑 부카채카2': 'P01',
#  '깨미탐험대': 'P04',
#  '깨미탐험대1(소장)': 'P06',
#  '깨비스토리': 'P01',
#  '깨비키즈 감성동화': 'P08',
#  '깨비키즈 건강관리': 'P02',
#  '깨비키즈 고조선과 삼국시대': 'P03',
#  '깨비키즈 공룡스토리': 'P02',
#  '깨비키즈 공룡호기심': 'P01',
#  '깨비키즈 교통안전': 'P04',
#  '깨비키즈 내몸과 성': 'P08',
#  '깨비키즈 도구와 기계': 'P04',
#  '깨비키즈 동물과 식물': 'P08',
#  '깨비키즈 똘이야 학교가자': 'P01',
#  '깨비키즈 뚝딱실험실': 'P01',
#  '깨비키즈 명작동화': 'P05',
#  '깨비키즈 문법모험': 'P08',
#  '깨비키즈 문장모험': 'P05',
#  '깨비키즈 바른생활동화': 'P08',
#  '깨비키즈 바른습관': 'P01',
#  '깨비키즈 생활안전': 'P04',
#  '깨비키즈 서바이벌 스토리': 'P04',
#  '깨비키즈 세익스피어 동화': 'P08',
#  '깨비키즈 아메리카 여행': 'P02',
#  '깨비키즈 유괴방지': 'P08',
#  '깨비키즈 유럽여행': 'P03',
#  '깨비키즈 이솝우화': 'P03',
#  '깨비키즈 자동차 구조대': 'P07',
#  '깨비키즈 전래동화': 'P01',
#  '깨비키즈 지구와 우주': 'P08',
#  '깨비키즈 직업탐험': 'P01',
#  '깨비키즈 통일신라와 후삼국': 'P06',
#  '꼬마 요리사': 'P04',
#  '꼬마기차 추추1': 'P03',
#  '꼬마기차 추추2': 'P02',
#  '꼬마농부 라비': 'P07',
#  '꼬마버스 타요1': 'P04',
#  '꼬마버스 타요1(영어)': 'P03',
#  '꼬마버스 타요2': 'P05',
#  '꼬마버스 타요2(영어)': 'P05',
#  '꼬마버스 타요3': 'P04',
#  '꼬마버스 타요3(영어)': 'P01',
#  '꼬마버스 타요4': 'P04',
#  '꼬마버스 타요5': 'P05',
#  '꼬마버스 타요5(영어)': 'P05',
#  '꼬마버스 타요6': 'P01',
#  '꼬마신선 타오1': 'P03',
#  '꼬마신선 타오2': 'P04',
#  '꼬마어사 쿵도령1': 'P08',
#  '꼬마캐빈의 아이캔두잇1': 'P08',
#  '꼬마캐빈의 아이캔두잇2': 'P01',
#  '꼬마탐정 토비와 테리1': 'P01',
#  '꼬마탐정 토비＆테리와 함께 배우며 놀아요': 'P06',
#  '꼬마히어로 슈퍼잭1 Part1': 'P05',
#  '꼬마히어로 슈퍼잭1 Part2': 'P04',
#  '꼬마히어로 슈퍼잭2': 'P02',
#  '꼬모 쿡': 'P04',
#  '꼬모는 궁금해': 'P01',
#  '꼬모와 감정표현': 'P06',
#  '꼬모와 잉글리시': 'P07',
#  '꼬모와 장난감1': 'P01',
#  '꼬모와 장난감2': 'P05',
#  '꼬모와 장난감3': 'P05',
#  '꼬모와 장난감4': 'P04',
#  '꼬모의 감정 나라': 'P04',
#  '꼬모의 놀이': 'P04',
#  '꼬모탐험대': 'P04',
#  '꼬미꼬미아꼼': 'P02',
#  '꼬불꼬불 ABC': 'P01',
#  '꼭꼭 약속해': 'P04',
#  '꽃잎(4단계) 레벨': 'P01',
#  '꾸러기 천사들': 'P01',
#  '꾸러기 케라톱스 코리요': 'P03',
#  '꾸미와 토리': 'P08',
#  '꿈과 직업': 'P04',
#  '꿈나라별 자장가': 'P05',
#  '꿈의 왕국 소피루비 Part1': 'P01',
#  '꿈의 왕국 소피루비 Part2': 'P04',
#  '꿈의왕국 소피루비 뮤직비디오': 'P08',
#  '나는 샛별반!': 'P04',
#  '나는 어디서 왔어요?': 'P04',
#  '나도 요리사': 'P01',
#  '나도 죠죠처럼 스스로 할래요!': 'P04',
#  '나도 죠죠처럼 스스로 할래요(영어)': 'P04',
#  '난감스쿨2': 'P05',
#  '낱말 단계': 'P03',
#  '내 친구 루피': 'P02',
#  '내 친구 에디': 'P05',
#  '내 친구 우줄리와 핍': 'P05',
#  '내 친구 크롱': 'P05',
#  '내 친구 티미 2.0-3': 'P04',
#  '내 친구 티미2.0-1': 'P08',
#  '내 친구 티미2.0-2': 'P04',
#  '내 친구 패티': 'P04',
#  '내 친구 호비1': 'P03',
#  '내 친구 호비2': 'P02',
#  '내 친구 호비3': 'P01',
#  '내 친구 호비4': 'P02',
#  '내 친구 호비5': 'P04',
#  '내 친구 호비6': 'P02',
#  '내 친구 호비7': 'P04',
#  '내 친구 호비8': 'P07',
#  '내 친구 호비9': 'P04',
#  '내 친구를 소개합니다': 'P04',
#  '내가 아끼는 책을 소개합니다 1~3편': 'P07',
#  '내가 아끼는 책을 소개합니다 4~6편': 'P03',
#  '내가 아끼는 책을 소개합니다 7~9편': 'P03',
#  '내사랑 뚱2': 'P02',
#  '내손안에 뽀로로': 'P02',
#  '내일은 실험왕1': 'P02',
#  '내일은 실험왕2': 'P02',
#  '내친구 코리리 Part1': 'P04',
#  '냉장고나라 코코몽1': 'P06',
#  '냉장고나라 코코몽1(영어)': 'P06',
#  '냉장고나라 코코몽2': 'P07',
#  '냉장고나라 코코몽2(영어)': 'P03',
#  '냉장고나라 코코몽3': 'P07',
#  '냉장고나라 코코몽3(영어)': 'P02',
#  '네모세모동글': 'P04',
#  '노래율동': 'P06',
#  '놀이교실': 'P08',
#  '놀이대장을 찾아라': 'P02',
#  '놀이터 구조대 뽀잉1': 'P05',
#  '놀이터 구조대 뽀잉2': 'P02',
#  '눈 건강 관리법': 'P07',
#  '다니엘 타이거1': 'P04',
#  '다이노 뽀로로': 'P05',
#  '다이노 뽀로로2': 'P08',
#  '다이노코어1': 'P04',
#  '다이노코어2': 'P05',
#  '다이노코어3': 'P08',
#  '다이노포스(영어)': 'P06',
#  '다큐동화 달팽이': 'P03',
#  '달님이랑 달콩이랑 행복동요': 'P04',
#  '달려라 호기심 친구들': 'P06',
#  '대교상상동화': 'P07',
#  '도와줘요 아이쿠': 'P02',
#  '동물원 이야기': 'P05',
#  '동물의 말': 'P01',
#  '동물일기': 'P03',
#  '동생이랑 나랑': 'P06',
#  '동요구출작전': 'P04',
#  '동화': 'P02',
#  '동화나라의 세계명작 매직랜턴3': 'P03',
#  '두근두근 궁금한 성': 'P05',
#  '두근두근 학교에 가면': 'P08',
#  '두다다쿵1': 'P04',
#  '두다다쿵2': 'P03',
#  '두다다쿵3: 신기한 동물탐험': 'P02',
#  '두둠칫 아꼼': 'P01',
#  '두리둥실 뭉게공항1': 'P08',
#  '두리둥실 뭉게공항2': 'P04',
#  '두리둥실 뭉게공항3': 'P08',
#  '두키 탐험대2': 'P04',
#  '둥실둥실 티니2': 'P04',
#  '드라마로 배우는 알파벳': 'P08',
#  '드래곤디 Dee Chat: 동물 달리기': 'P04',
#  '드래곤디 나도 선생님': 'P03',
#  '드래곤디 냠냠 간식 게임': 'P06',
#  '드래곤디 냠냠간식송': 'P06',
#  '드래곤디 니토이 내토이': 'P06',
#  '드래곤디 동물 달리기송': 'P04',
#  '드래곤디 동물 달리기송2': 'P05',
#  '드래곤디 마더구스 인기전래동요': 'P02',
#  '드래곤디 벨라 가족의 바람': 'P08',
#  '드래곤디 벨라 가족의 절대송': 'P06',
#  '드래곤디 사탕보다 달콤한 사랑 고백송': 'P08',
#  '드래곤디 새해맞이 암기송': 'P02',
#  '드래곤디 세계 나라 암기송': 'P08',
#  '드래곤디 악땅 찾아라': 'P08',
#  '드래곤디 애니멀 히어로즈': 'P06',
#  '드래곤디 애니멀 히어로즈 게임': 'P03',
#  '드래곤디 애니멀러쉬! 게임＆율동': 'P05',
#  '드래곤디 와글와글 아기 동물송': 'P04',
#  '드래곤디 위기탈출 랩배틀': 'P06',
#  '드래곤디 율동 디디댄스': 'P02',
#  '드래곤디 으스스 할로윈송': 'P04',
#  '드래곤디 크리스마스 캐럴 시리즈': 'P08',
#  '디즈니 프린세스': 'P04',
#  '디즈니러닝': 'P04',
#  '딩동댕 유치원(2016)': 'P08',
#  '딩동댕 유치원(2017)': 'P08',
#  '딩동댕 유치원(2018)': 'P02',
#  '딩동댕 유치원(2019)': 'P02',
#  '딩동댕 유치원(2020)': 'P01',
#  '딩동댕 유치원(2021)': 'P04',
#  '딩동댕 유치원(2022)': 'P04',
#  '딩동댕 유치원(~2015)': 'P03',
#  '딩동댕 친구들 장난감 나라의 비밀': 'P05',
#  '딩딩코딩': 'P01',
#  '딩딩코딩2': 'P01',
#  '딩딩코딩3': 'P04',
#  '딩딩코딩4': 'P05',
#  '따개비루': 'P04',
#  '따개비루(영어)': 'P05',
#  '따끈따끈한 신작이 왔어요!': 'P08',
#  '따르릉 비켜나세요': 'P04',
#  '떠나볼까 랜선동물원': 'P03',
#  '떠나요! 기이한 공룡탐험1': 'P04',
#  '또깨비 가족': 'P08',
#  '또깨비 가족 시즌2': 'P04',
#  '또또랑 보물창고': 'P08',
#  '또또바를 찾아라': 'P05',
#  '또보는노부영': 'P02',
#  '또봇 연대기 Part1 또봇의 시작': 'P06',
#  '또봇V 2 Part1': 'P06',
#  '또봇V 2 Part2': 'P02',
#  '또봇V Part1': 'P04',
#  '또봇V Part2': 'P03',
#  '또봇V 갤럭시웨폰 4호의 비밀': 'P03',
#  '똑게육아 올인원': 'P05',
#  '똑딱똑딱': 'P06',
#  '똑똑박사 에디1': 'P08',
#  '똑똑박사 에디2': 'P08',
#  '똑똑박사 에디동요1': 'P04',
#  '똑똑박사 에디동요2': 'P04',
#  '뚜기와 따기': 'P03',
#  '뚜비뚜바 눈보리2': 'P06',
#  '뚝딱뚝딱 발명왕': 'P04',
#  '뚝딱맨': 'P05',
#  '띠띠뽀 띠띠뽀1': 'P03',
#  '띠띠뽀 띠띠뽀2': 'P02',
#  '띠띠뽀 띠띠뽀3': 'P02',
#  '띠띠뽀 세계인기동요': 'P04',
#  '띠띠뽀 세계인기동요(영어)': 'P03',
#  '띠띠뽀 율동동요': 'P08',
#  '띠띠뽀 인기동요': 'P07',
#  '띠띠뽀 클래식 동요': 'P02',
#  '띠띠뽀 탐구생활': 'P05',
#  '띠띠뽀 탐구생활(소장)': 'P05',
#  '띠띠뽀 탐구생활2': 'P05',
#  '띠띠뽀와 노래해요': 'P03',
#  '띠띠뽀의 스토리＆송': 'P05',
#  '띠띠뽀의 친구를 소개합니다': 'P04',
#  '띠띠뽀의 친구를 소개합니다(소장)': 'P03',
#  '띵동! 캐리있어요? 2': 'P01',
#  '라바 리믹스': 'P03',
#  '라바 인 뉴욕1': 'P05',
#  '라바 인 뉴욕2': 'P05',
#  '라바 인 뉴욕3': 'P03',
#  '라바 인 뉴욕4': 'P07',
#  '라바 키즈동요 PHONICS': 'P07',
#  '라바1': 'P01',
#  '라바2': 'P05',
#  '라바와 함께 즐거운 게임': 'P05',
#  '라바키즈 생활동요': 'P07',
#  '라바키즈 생활동요(영어)': 'P08',
#  '라바키즈 클레이 만들기': 'P07',
#  '라바키즈 클레이 만들기(영어)': 'P03',
#  '라바키즈 한국어 동요': 'P04',
#  '라바키즈동요5': 'P03',
#  '랄랄라 뿌우': 'P04',
#  '럭키강이': 'P03',
#  '레오와 티그1': 'P05',
#  '레오와 티그2': 'P07',
#  '레이의 우주대모험': 'P08',
#  '레전드히어로 삼국전': 'P04',
#  '로보카 폴리 교통안전 이야기': 'P07',
#  '로보카 폴리1': 'P02',
#  '로보카 폴리1(영어)': 'P02',
#  '로보카 폴리2': 'P05',
#  '로보카 폴리2(영어)': 'P01',
#  '로보카 폴리3': 'P04',
#  '로보카 폴리3(영어)': 'P08',
#  '로보카 폴리4': 'P05',
#  '로보카 폴리4(영어)': 'P04',
#  '로보카 폴리5 Part1': 'P05',
#  '로보카폴리 ABC 숫자공부 동요': 'P04',
#  '로보카폴리 OST': 'P04',
#  '로보카폴리 고니의 클레이 타운': 'P02',
#  '로보카폴리 공룡동요': 'P04',
#  '로보카폴리 공룡탐험': 'P04',
#  '로보카폴리 교육 동요': 'P07',
#  '로보카폴리 구조도구 퀴즈': 'P05',
#  '로보카폴리 글로우컬러링': 'P05',
#  '로보카폴리 놀이동요': 'P05',
#  '로보카폴리 생활안전 이야기': 'P04',
#  '로보카폴리 소방안전 뮤직비디오': 'P07',
#  '로보카폴리 소방안전 이야기': 'P05',
#  '로보카폴리 스스로 안전 캠페인(소방편)': 'P05',
#  '로보카폴리 쏭쏭뮤지엄': 'P08',
#  '로보카폴리 인기동요': 'P05',
#  '로보카폴리 자동차동요': 'P02',
#  '로보카폴리 자동차동요2': 'P05',
#  '로보카폴리 크리스마스송': 'P05',
#  '로보카폴리 크리스마스송(영어)': 'P04',
#  '로보카폴리 크리스마스송2': 'P07',
#  '로보카폴리 터치터치 율동체조(영어)': 'P07',
#  '로보카폴리 터치터치 율동체조-율동편': 'P02',
#  '로보카폴리 터치터치 율동체조-체조편': 'P02',
#  '로보카폴리 토이폴리1': 'P06',
#  '로보카폴리 토이폴리2': 'P05',
#  '로보카폴리 토이폴리3': 'P05',
#  '로보카폴리 해피할로윈': 'P04',
#  '로봇트레인1': 'P06',
#  '롤러코스터보이 노리': 'P03',
#  '루시의 똑똑동화': 'P04',
#  '루키로봇': 'P03',
#  '리딩게이트': 'P03',
#  '리키줌1': 'P05',
#  '리틀베이비범 냠냠 동요': 'P04',
#  '리틀베이비범 댄스댄스 송': 'P05',
#  '리틀베이비범 동물 동요1': 'P07',
#  '리틀베이비범 동물 동요2': 'P05',
#  '리틀베이비범 동물 동요3': 'P02',
#  '리틀베이비범 동물 동요4': 'P04',
#  '리틀베이비범 러닝동요': 'P04',
#  '리틀베이비범 바른습관동요': 'P04',
#  '리틀베이비범 버스 동요1': 'P04',
#  '리틀베이비범 버스 동요2': 'P04',
#  '리틀베이비범 색과 모양 동요': 'P04',
#  '리틀베이비범 생활 동요1': 'P04',
#  '리틀베이비범 생활습관 동요': 'P02',
#  '리틀베이비범 숫자 동요1': 'P02',
#  '리틀베이비범 숫자 동요2': 'P07',
#  '리틀베이비범 시즌 송': 'P05',
#  '리틀베이비범 신나는 러닝쏭': 'P04',
#  '리틀베이비범 자동차 동요': 'P04',
#  '리틀베이비범 크리스마스 노래': 'P03',
#  '리틀베이비범 퍼니퍼니 송1': 'P05',
#  '리틀베이비범 퍼니퍼니 송2': 'P02',
#  '리틀베이비범 퍼니퍼니 송3': 'P05',
#  '리틀베이비범 해외 인기 동요1': 'P03',
#  '리틀베이비범 해외 인기 동요10': 'P05',
#  '리틀베이비범 해외 인기 동요2': 'P02',
#  '리틀베이비범 해외 인기 동요3': 'P06',
#  '리틀베이비범 해외 인기 동요4': 'P06',
#  '리틀베이비범 해외 인기 동요5': 'P05',
#  '리틀베이비범 해외 인기 동요6': 'P02',
#  '리틀베이비범 해외 인기 동요7': 'P05',
#  '리틀베이비범 해외 인기 동요8': 'P04',
#  '리틀베이비범 해외 인기 동요9': 'P07',
#  '리틀베이비범 해외동화 베스트': 'P02',
#  '리틀베이비범과 함께하는 ABC': 'P07',
#  '리틀베이비범과 함께하는 ABC2': 'P07',
#  '리틀스톤즈': 'P01',
#  '리틀스톤즈(소장)': 'P04',
#  '리틀투니 인기동요 노래방': 'P08',
#  '리틀투니 인기동요1': 'P04',
#  '마녀스쿨': 'P08',
#  '마법버스 타요': 'P04',
#  '마법천자문1': 'P03',
#  '마샤와 곰1': 'P03',
#  '마샤와 곰2': 'P05',
#  '마샤와 곰3': 'P04',
#  '마샤와 노래해요': 'P02',
#  '마샤의 무서운 이야기': 'P08',
#  '마샤의 이야기': 'P08',
#  '마이 리틀 포니 1': 'P08',
#  '마이 리틀 포니 2': 'P07',
#  '마이 리틀 포니 3': 'P08',
#  '마이 리틀 포니 4': 'P04',
#  '마이 리틀 포니 5': 'P08',
#  '마이 리틀 포니 6': 'P08',
#  '마이 리틀 포니 7': 'P05',
#  '마이 리틀 포니 8': 'P04',
#  '마인크래프트 이야기2: 반이와 바로의 마인크래프트 이야기 1': 'P05',
#  '마카앤로니': 'P01',
#  '만 3세를 위한 영상': 'P07',
#  '만 4세를 위한 영상': 'P03',
#  '만 5세를 위한 영상': 'P03',
#  '만들어 볼까요': 'P07',
#  '만렙키즈1': 'P05',
#  '말이 늦은 아이 속이 타는 부모': 'P05',
#  '먹보공룡 티노': 'P05',
#  '메탈리온 1 Part1': 'P05',
#  '메탈리온 1 Part2': 'P01',
#  '메탈리온 2 Part1': 'P01',
#  '메탈리온 2 Part2': 'P02',
#  '명탐정 피트1': 'P08',
#  '명탐정 피트2': 'P08',
#  '모두모두 쇼': 'P03',
#  '모두보기': 'P05',
#  '모모로운 생활1': 'P04',
#  '모아모아 금융동화': 'P08',
#  '모여라 딩동댕': 'P01',
#  '모프의 위대한 모험': 'P02',
#  '모험 이야기': 'P05',
#  '몬스터 대소동1': 'P05',
#  '몬스터 대소동3': 'P01',
#  '몬스터 주식회사': 'P05',
#  '몬카트': 'P01',
#  '몰랑': 'P01',
#  '몸도 튼튼, 마음도 튼튼': 'P04',
#  '못말리는 어린 양 숀3': 'P04',
#  '못말리는 어린 양 숀4': 'P08',
#  '무스티': 'P05',
#  '문정아 중국어': 'P08',
#  '뭐든지 뮤직박스1': 'P05',
#  '뭐든지 뮤직박스2': 'P05',
#  '뭐든지 뮤직박스3': 'P05',
#  '뮤지컬 헬로카봇 5: 별똥별을 지켜라!': 'P08',
#  '미니특공대 슈퍼공룡파워 Part1': 'P04',
#  '미니특공대 슈퍼공룡파워 Part2': 'P05',
#  '미니특공대 율동 동요1': 'P05',
#  '미니특공대 율동 동요2': 'P01',
#  '미니특공대 키즈 놀이1': 'P08',
#  '미니특공대 키즈 놀이2': 'P05',
#  '미니특공대 키즈 놀이3': 'P05',
#  '미니특공대 프리스쿨1': 'P03',
#  '미니특공대 프리스쿨2': 'P08',
#  '미니특공대 프리스쿨3': 'P07',
#  '미니특공대X Part1': 'P08',
#  '미니특공대X Part2: 펜타트론': 'P02',
#  '미술탐험대': 'P03',
#  '미오마오': 'P02',
#  '미키와 친구들': 'P02',
#  '미피의 모험': 'P01',
#  '바나나를 탄 끼끼<음악>': 'P06',
#  '바나나를 탄 끼끼<한글>': 'P08',
#  '바나나차차': 'P07',
#  '바나나차차 뮤직비디오': 'P06',
#  '바나나차차 뮤직비디오2': 'P03',
#  '바나나차차 율동해요': 'P06',
#  '바다 탐험대 옥토넛 움직이는 동화': 'P03',
#  '바다 탐험대 옥토넛 캐릭터 그리기': 'P06',
#  '바다나무 너서리 라임 컬렉션': 'P04',
#  '바다나무 베이비 팝 컬렉션(영어)': 'P04',
#  '바다나무 생활동요 sing': 'P06',
#  '바다나무 어휘 학습 컬렉션(영어)': 'P06',
#  '바다나무 영어로 놀아요': 'P04',
#  '바다나무 카뎃 (영어)': 'P05',
#  '바다의 비밀': 'P01',
#  '바다탐험대 옥토넛 탐험선 보고': 'P04',
#  '바다탐험대 옥토넛1': 'P02',
#  '바다탐험대 옥토넛1 (영어)': 'P01',
#  '바다탐험대 옥토넛2': 'P02',
#  '바다탐험대 옥토넛2 (영어)': 'P01',
#  '바다탐험대 옥토넛2(소장)': 'P05',
#  '바다탐험대 옥토넛3': 'P02',
#  '바다탐험대 옥토넛3 (영어)': 'P05',
#  '바다탐험대 옥토넛4': 'P03',
#  '바닷속 친구들': 'P04',
#  '반짝반짝 달님이': 'P04',
#  '방귀대장 뿡뿡이(2011-12)': 'P02',
#  '방귀대장 뿡뿡이(2013-14)': 'P01',
#  '방귀대장 뿡뿡이(2015-16)': 'P03',
#  '방귀대장 뿡뿡이(2017)': 'P07',
#  '방귀대장 뿡뿡이(2020)': 'P08',
#  '방귀대장 뿡뿡이(2021)': 'P05',
#  '버블버블 마린': 'P07',
#  '베리와 안녕이의 슬기로운 탐구생활': 'P08',
#  '베베 뮤직스토리': 'P02',
#  '베베 생활습관': 'P04',
#  '베베 신체표현': 'P03',
#  '베베 아이놀이': 'P02',
#  '베베 엄마와 놀이': 'P07',
#  '베베 창의발화': 'P04',
#  '베스트셀러': 'P02',
#  '베이비돌리와 장난감 친구들1': 'P03',
#  '베이비돌리와 장난감 친구들2': 'P03',
#  '베이비돌리와 장난감 친구들3': 'P04',
#  '베이비돌리와 장난감 친구들4': 'P02',
#  '베이비버스': 'P01',
#  '베이비버스 감정 표현 동요': 'P02',
#  '베이비버스 감정 표현 동요2': 'P08',
#  '베이비버스 공룡동요': 'P08',
#  '베이비버스 공룡동요2': 'P04',
#  '베이비버스 교통수단 동요': 'P03',
#  '베이비버스 교통수단 동요 레드(영어)': 'P04',
#  '베이비버스 교통수단 동요 블루(영어)': 'P04',
#  '베이비버스 교통수단 동요2': 'P04',
#  '베이비버스 교통수단 동요3': 'P06',
#  '베이비버스 구조대 동요(영어)': 'P04',
#  '베이비버스 기차동요': 'P04',
#  '베이비버스 동계올림픽 동요': 'P05',
#  '베이비버스 동화1': 'P04',
#  '베이비버스 동화2': 'P04',
#  '베이비버스 마법숫자동화': 'P07',
#  '베이비버스 명절동요': 'P02',
#  '베이비버스 몬스터차 동요 레드(영어)': 'P05',
#  '베이비버스 몬스터차 동요 블루(영어)': 'P02',
#  '베이비버스 몬스터트럭 동요': 'P04',
#  '베이비버스 몬스터트럭 동요2': 'P05',
#  '베이비버스 뮤직비디오': 'P05',
#  '베이비버스 바다동물동요': 'P07',
#  '베이비버스 배워봐요 자동차': 'P05',
#  '베이비버스 버디월드': 'P01',
#  '베이비버스 베이비키키동화': 'P01',
#  '베이비버스 생활 습관 동요 레드(영어)': 'P04',
#  '베이비버스 생활 안전 동요 그린(영어)': 'P01',
#  '베이비버스 생활 안전 동요 레드(영어)': 'P08',
#  '베이비버스 생활안전동요': 'P08',
#  '베이비버스 생활안전동요2': 'P02',
#  '베이비버스 생활안전동요3': 'P04',
#  '베이비버스 생활인지동요': 'P04',
#  '베이비버스 세균동요': 'P04',
#  '베이비버스 스토리동화1': 'P03',
#  '베이비버스 스토리동화2': 'P03',
#  '베이비버스 어드벤처1': 'P03',
#  '베이비버스 어드벤처2': 'P06',
#  '베이비버스 어드벤처3': 'P05',
#  '베이비버스 역할놀이동요': 'P03',
#  '베이비버스 음식동요': 'P04',
#  '베이비버스 음식동요2': 'P08',
#  '베이비버스 음식동요3': 'P05',
#  '베이비버스 음식친구 동화': 'P04',
#  '베이비버스 인기 동요 레드(영어)': 'P08',
#  '베이비버스 인기 동요 블루(영어)': 'P05',
#  '베이비버스 인기동요1': 'P05',
#  '베이비버스 인기동요2': 'P03',
#  '베이비버스 인기동요3': 'P03',
#  '베이비버스 인지발달동요': 'P05',
#  '베이비버스 일상생활동요': 'P04',
#  '베이비버스 좋은습관동요1': 'P04',
#  '베이비버스 좋은습관동요2(3D)': 'P04',
#  '베이비버스 좋은습관동요3(3D)': 'P08',
#  '베이비버스 좋은습관동요4': 'P02',
#  '베이비버스 직업그림책 동화': 'P07',
#  '베이비버스 직업체험 동요 레드(영어)': 'P08',
#  '베이비버스 직업체험 동요 블루(영어)': 'P08',
#  '베이비버스 직업체험 동요 옐로우(영어)': 'P04',
#  '베이비버스 직업체험동요1': 'P04',
#  '베이비버스 직업체험동요2': 'P08',
#  '베이비버스 직업체험동요3': 'P08',
#  '베이비버스 직업체험동요4': 'P05',
#  '베이비버스 크리스마스동요': 'P02',
#  '베이비버스 키키묘묘구조대': 'P07',
#  '베이비버스 키키묘묘구조대 동요': 'P03',
#  '베이비버스 키키묘묘구조대 동요2': 'P01',
#  '베이비버스 할로윈 동요': 'P08',
#  '베이비버스 할로윈 동요2': 'P05',
#  '베이비버스 행복한 가족 동요': 'P05',
#  '베이비버스 환경보호 동요': 'P08',
#  '변신기차 로봇트레인S2': 'P03',
#  '변신로봇5 시즌3': 'P08',
#  '변신로봇5 시즌4': 'P01',
#  '변신자동차 또봇 미션여행': 'P06',
#  '변신자동차 또봇1': 'P01',
#  '변신자동차 또봇10': 'P06',
#  '변신자동차 또봇11': 'P01',
#  '변신자동차 또봇12': 'P08',
#  '변신자동차 또봇13': 'P02',
#  '변신자동차 또봇14': 'P06',
#  '변신자동차 또봇15': 'P03',
#  '변신자동차 또봇16': 'P01',
#  '변신자동차 또봇17': 'P02',
#  '변신자동차 또봇17(소장)': 'P06',
#  '변신자동차 또봇18': 'P06',
#  '변신자동차 또봇19': 'P06',
#  '변신자동차 또봇2': 'P02',
#  '변신자동차 또봇3': 'P03',
#  '변신자동차 또봇4': 'P02',
#  '변신자동차 또봇5': 'P03',
#  '변신자동차 또봇6': 'P03',
#  '변신자동차 또봇8': 'P03',
#  '변신자동차 또봇9': 'P03',
#  '별별 패밀리': 'P05',
#  '보글보글': 'P06',
#  '보글보글 율동해요': 'P07',
#  '보리스': 'P03',
#  '보물을 찾아라!': 'P04',
#  '보보1': 'P03',
#  '보보2': 'P03',
#  '보이즈앤걸즈 스페셜': 'P01',
#  '볼쇼이 발레단의 심장을 가다': 'P08',
#  '볼츠와 블립': 'P04',
#  '봉구야 말해줘2': 'P02',
#  '봉구야 말해줘3': 'P08',
#  '부릉부릉 부르미즈3': 'P02',
#  '부릉부릉 부르미지1': 'P05',
#  '부릉부릉 부르미지2': 'P03',
#  '부모베스트': 'P05',
#  '브룸스타운 극장: 로보카폴리 이솝우화': 'P08',
#  '블루피스': 'P04',
#  '빛나는 나라1': 'P01',
#  '빼꼼1': 'P04',
#  '빼꼼2': 'P01',
#  '빼꼼3': 'P01',
#  '뽀글아 사랑해1': 'P04',
#  '뽀로로 ABC': 'P08',
#  '뽀로로 ㄱㄴㄷ 한글놀이': 'P05',
#  '뽀로로 ㅏㅑㅓㅕ 한글놀이': 'P07',
#  '뽀로로 가나다라 이야기책': 'P05',
#  '뽀로로 감정동화': 'P07',
#  '뽀로로 겨울동요': 'P05',
#  '뽀로로 곤충동요': 'P04',
#  '뽀로로 공룡놀이1': 'P04',
#  '뽀로로 공룡놀이1(영어)': 'P03',
#  '뽀로로 공룡놀이2': 'P05',
#  '뽀로로 공룡송 모음': 'P04',
#  '뽀로로 공룡송 모음2': 'P05',
#  '뽀로로 교통안전동요': 'P05',
#  '뽀로로 나도나도 동요': 'P06',
#  '뽀로로 놀면 뭐하니?': 'P05',
#  '뽀로로 동물 동요': 'P07',
#  '뽀로로 동물 율동해요': 'P05',
#  '뽀로로 동요 메들리': 'P05',
#  '뽀로로 동화나라': 'P04',
#  '뽀로로 동화동요': 'P07',
#  '뽀로로 말놀이 수놀이 동요': 'P06',
#  '뽀로로 뮤직박스': 'P08',
#  '뽀로로 뮤직비디오1': 'P05',
#  '뽀로로 뮤직비디오2': 'P04',
#  '뽀로로 뮤직비디오3': 'P04',
#  '뽀로로 미니동화': 'P03',
#  '뽀로로 바다동물 동요': 'P03',
#  '뽀로로 베이비동요': 'P05',
#  '뽀로로 변신직업놀이': 'P08',
#  '뽀로로 병원놀이 동요': 'P05',
#  '뽀로로 병원놀이 동요(영어)': 'P08',
#  '뽀로로 병원놀이 동화': 'P03',
#  '뽀로로 병원에 놀러가요': 'P04',
#  '뽀로로 상어동요': 'P04',
#  '뽀로로 생생태권댄스': 'P05',
#  '뽀로로 생활습관 동요1': 'P08',
#  '뽀로로 생활습관 동요2': 'P02',
#  '뽀로로 설날 키즈팝 콘서트': 'P01',
#  '뽀로로 세계명작 동화1': 'P03',
#  '뽀로로 세계명작 동화2': 'P07',
#  '뽀로로 소리동요': 'P03',
#  '뽀로로 스페셜 동화': 'P03',
#  '뽀로로 안전캠페인': 'P03',
#  '뽀로로 여름놀이 동요': 'P05',
#  '뽀로로 영어율동 동요': 'P02',
#  '뽀로로 율동동요': 'P07',
#  '뽀로로 율동체조': 'P05',
#  '뽀로로 이야기 동요1': 'P08',
#  '뽀로로 이야기 동요2': 'P05',
#  '뽀로로 인기동요 베스트': 'P02',
#  '뽀로로 인기동요1': 'P05',
#  '뽀로로 인기동요2': 'P06',
#  '뽀로로 인기동요3': 'P05',
#  '뽀로로 인기동화': 'P04',
#  '뽀로로 인성동화': 'P08',
#  '뽀로로 잉글리쉬쇼(영어)': 'P04',
#  '뽀로로 자동차동요': 'P04',
#  '뽀로로 자동차동요2': 'P05',
#  '뽀로로 전래동요 동화': 'P02',
#  '뽀로로 지구탐험 동화': 'P07',
#  '뽀로로 추천 동요1': 'P06',
#  '뽀로로 친구들과 사이좋게 지내요': 'P02',
#  '뽀로로 캐릭터 모음': 'P02',
#  '뽀로로 컬러송': 'P02',
#  '뽀로로 크리스마스 동요': 'P05',
#  '뽀로로 테마극장1': 'P03',
#  '뽀로로 토이 동요1': 'P02',
#  '뽀로로 토이 동요2': 'P04',
#  '뽀로로 토이스토리': 'P03',
#  '뽀로로 페이퍼 플레이 JOB': 'P02',
#  '뽀로로 한글놀이': 'P05',
#  '뽀로로 한글동요': 'P08',
#  '뽀로로랑 냠냠냠': 'P08',
#  '뽀로로랑 뿡뿡뿡': 'P08',
#  '뽀로로와 공룡 친구들': 'P08',
#  '뽀로로와 노래해요3': 'P05',
#  '뽀로로와 노래해요3(소장)': 'P06',
#  '뽀로로와 동물 친구들(영어)': 'P07',
#  '뽀로로와 동물친구들': 'P05',
#  '뽀로로와 루피의 모험': 'P05',
#  '뽀로로와 루피의 모험(소장)': 'P08',
#  '뽀로로와 루피의 모험(영어)': 'P05',
#  '뽀로로와 율동해요1': 'P04',
#  '뽀로로와 율동해요2': 'P05',
#  '뽀로로와 집에서 놀아요': 'P08',
#  '뽀로로와 크롱의 우당탕탕 아기 돌보기': 'P05',
#  '뽀로로와 타요의 동요5': 'P05',
#  '뽀로로와 타요의 할로윈 축제': 'P05',
#  '뽀로로와 함께하는 세계여행': 'P06',
#  '뽀로로의 겨울왕국': 'P04',
#  '뽀로로의 그것을 알려 줄까': 'P05',
#  '뽀로로의 스토리＆송': 'P05',
#  '뽀로로의 신나는 우주여행': 'P04',
#  '뽀로로의 씽씽극장': 'P03',
#  '뽀로로의 올바른 생활습관': 'P08',
#  '뽀로로의 왜요쇼': 'P04',
#  '뽀로로의 이럴 땐 어떡하지': 'P04',
#  '뽀로로의 친구를 소개합니다': 'P06',
#  '뽀로로의 하루': 'P08',
#  '뽀로로차차': 'P06',
#  '뽀로로픽': 'P03',
#  '뽀로로＆타요 인기작 이어보기': 'P04',
#  '뽀로로＆타요 크리스마스 콘서트': 'P04',
#  '뽀로로＆타요와 손 씻기': 'P07',
#  '뽀롱뽀롱 뽀로로1(영어)': 'P07',
#  '뽀롱뽀롱 뽀로로2': 'P05',
#  '뽀롱뽀롱 뽀로로2(영어)': 'P05',
#  '뽀롱뽀롱 뽀로로3': 'P04',
#  '뽀롱뽀롱 뽀로로3(영어)': 'P08',
#  '뽀롱뽀롱 뽀로로4': 'P05',
#  '뽀롱뽀롱 뽀로로4(영어)': 'P03',
#  '뽀롱뽀롱 뽀로로5': 'P05',
#  '뽀롱뽀롱 뽀로로5(소장)': 'P05',
#  '뽀롱뽀롱 뽀로로5(영어)': 'P03',
#  '뽀롱뽀롱 뽀로로6': 'P06',
#  '뽀롱뽀롱 뽀로로6(소장)': 'P04',
#  '뽀롱뽀롱 뽀로로6(영어)': 'P05',
#  '뽀롱뽀롱 뽀로로7': 'P06',
#  '뽀롱뽀롱 상어 비밀작전': 'P04',
#  '뽀롱뽀롱 상어 비밀작전 (소장)': 'P04',
#  '뽀롱뽀롱 퀴즈쇼': 'P07',
#  '뽀롱뽀롱 한글나라': 'P01',
#  '뽀뽀뽀 친구친구': 'P03',
#  '뽀뽀뽀 친구친구2': 'P01',
#  '뽀뽀뽀 친구친구3': 'P08',
#  '뽀뽀뽀 친구친구4': 'P04',
#  '뽀뽀뽀 친구친구5': 'P02',
#  '뽀스타그램': 'P07',
#  '뽀스타그램2': 'P03',
#  '뽀요극장': 'P05',
#  '뽀요뽀요 뉴스': 'P01',
#  '뽀요뽀요 뉴스2': 'P05',
#  '뽀요뽀요 영상통화': 'P01',
#  '뽀요뽀요 이야기 자판기': 'P07',
#  '뽀요뽀요 차트쇼1': 'P01',
#  '뽀요뽀요 차트쇼2': 'P03',
#  '삐뽀삐뽀! 우리 몸 X 파일': 'P02',
#  '삐약삐약 어디일까요?': 'P04',
#  '사고뭉치 모리': 'P04',
#  '사라앤덕1(영어)': 'P02',
#  '사라앤덕2(영어)': 'P01',
#  '사라앤덕3(영어)': 'P02',
#  '사랑하는 내 친구': 'P04',
#  '사이먼스캣': 'P03',
#  '사이틴1': 'P01',
#  '사이틴2-백만이의 지구뉴스': 'P01',
#  '사이틴3: 왔다! 사춘기': 'P03',
#  '산후다이어트': 'P05',
#  '새싹(2단계) 레벨': 'P05',
#  '선물공룡 디보1': 'P05',
#  '선물공룡 디보2': 'P04',
#  '성교육': 'P04',
#  '성장을 돕는 베이비 마사지': 'P04',
#  '성장을 돕는 수면 관리와 교육': 'P05',
#  '세미와 매직큐브': 'P08',
#  '세미와 매직큐브2': 'P05',
#  '세상에서 제일 작은 남자': 'P08',
#  '세상의 모든 오싹오싹 이야기': 'P03',
#  '소근육 발달편': 'P06',
#  '소중한 가족': 'P04',
#  '소중한 우정을 다룬 이야기를 만나보아요': 'P08',
#  '소피루비 Part1': 'P08',
#  '소피루비 Part2': 'P01',
#  '속담이 야호': 'P08',
#  '손이 꽁꽁, 발이 꽁꽁': 'P04',
#  '쇼 미 더 컬러': 'P02',
#  '수학교실': 'P08',
#  '수학이 야호': 'P07',
#  '숫자와 즐거운 여행': 'P08',
#  '숫자특공대1': 'P04',
#  '숲속 대장 나르고1': 'P04',
#  '숲속 배달부 빙빙': 'P07',
#  '숲의 요정 페어리루2 Part2': 'P04',
#  '쉿! 내 친구는 빅파이브 비디오북': 'P05',
#  '쉿! 내 친구는 빅파이브1': 'P05',
#  '쉿! 내 친구는 빅파이브2': 'P04',
#  '슈퍼와이3': 'P04',
#  '슈퍼와이3 (영어)': 'P07',
#  '스노우볼': 'P05',
#  '스마이티': 'P04',
#  '스쿨랜드-틴틴인터뷰': 'P05',
#  '스쿨랜드-한자왕국': 'P08',
#  '스티브코딩': 'P01',
#  '스페셜': 'P08',
#  '스페이스 정글2': 'P05',
#  '스폐셜': 'P04',
#  '스푸키즈1': 'P06',
#  '스푸키즈2': 'P06',
#  '스푸키즈3': 'P05',
#  '시간을 달리는 세계사': 'P06',
#  '시계마을 티키톡1': 'P03',
#  '시계마을 티키톡2(소장)': 'P07',
#  '신기한 수학나라': 'P08',
#  '신기한 한글나라': 'P01',
#  '신비금비송': 'P04',
#  '신비금비송 Part2': 'P01',
#  '신비와 노래해요 고스트 인기동요': 'P04',
#  '신비와 노래해요 고스트 인기동요2': 'P03',
#  '신비와 노래해요 영어 인기동요': 'P04',
#  '신비와 노래해요2': 'P07',
#  '써니 타운 ABC2': 'P04',
#  '써니버니 1': 'P04',
#  '써니버니2': 'P02',
#  '써니버니3': 'P04',
#  '써니버니4': 'P04',
#  '쑥쑥(3단계) 레벨': 'P04',
#  '아기공룡 버디1': 'P02',
#  '아기공룡 버디2': 'P06',
#  '아기공룡 버디3': 'P04',
#  '아기공룡 버디4': 'P01',
#  ...}

# %%
new_par_try = new_par_fu.fillna('nan')
new_par_try
# Out:
#        album_id   sub_title pr_int
# 0           749    꼬마버스 타요1    P05
# 1           750    꼬마버스 타요1    P05
# 2          2131    꼬마버스 타요1    P05
# 3          2625    꼬마버스 타요1    P05
# 4          2594    꼬마버스 타요1    P05
# ...         ...         ...    ...
# 39870     39872  로티프렌즈 미술놀이    nan
# 39871     39873  로티프렌즈 미술놀이    nan
# 39872     39874  로티프렌즈 미술놀이    nan
# 39873      4779        4-5세    nan
# 39874     11629  베이비 타요 동요2    nan
#
# [39875 rows x 3 columns]

# %%
new_par_try.loc[new_par_try['pr_int'] == 'nan']
# 현재 결측 19514
# Out:
#        album_id   sub_title pr_int
# 26        26077   변신자동차 또봇2    NaN
# 27        26078   변신자동차 또봇2    NaN
# 28        26079   변신자동차 또봇2    NaN
# 30        26080   변신자동차 또봇1    NaN
# 31        13771   변신자동차 또봇1    NaN
# ...         ...         ...    ...
# 39870     39872  로티프렌즈 미술놀이    NaN
# 39871     39873  로티프렌즈 미술놀이    NaN
# 39872     39874  로티프렌즈 미술놀이    NaN
# 39873      4779        4-5세    NaN
# 39874     11629  베이비 타요 동요2    NaN
#
# [19514 rows x 3 columns]

# %%
cnt = 0
for i in new_par_try.itertuples():
    if i[3] == 'nan':
        if i[2] in meta_subtitle_key_dict.keys():
            new_par_try.loc[i[0], 'pr_int'] = meta_subtitle_key_dict[i[2]]
        else:
            cnt += 1

# %%
new_par_try
# Out:
#        album_id   sub_title pr_int
# 0           749    꼬마버스 타요1    P05
# 1           750    꼬마버스 타요1    P05
# 2          2131    꼬마버스 타요1    P05
# 3          2625    꼬마버스 타요1    P05
# 4          2594    꼬마버스 타요1    P05
# ...         ...         ...    ...
# 39870     39872  로티프렌즈 미술놀이    nan
# 39871     39873  로티프렌즈 미술놀이    nan
# 39872     39874  로티프렌즈 미술놀이    nan
# 39873      4779        4-5세    P01
# 39874     11629  베이비 타요 동요2    nan
#
# [39875 rows x 3 columns]

# %%
new_par_try['album_id'].value_counts()
# Out:
# 749      1
# 17056    1
# 15212    1
# 12126    1
# 12124    1
#         ..
# 5407     1
# 5406     1
# 32275    1
# 22598    1
# 11629    1
# Name: album_id, Length: 39875, dtype: int64

# %%
meta_genre_with_keyowrd
# Out:
#        album_id genre_mid pr_int
# 0           749      TV만화    P04
# 1           750      TV만화    P04
# 2          2131      TV만화    P04
# 3          2625      TV만화    P04
# 4          2594      TV만화    P04
# ...         ...       ...    ...
# 39850      6302        한글    P08
# 39851      6303        한글    P08
# 39852      6309        한글    P08
# 39853      6310        한글    P08
# 39854      8264        한글    P08
#
# [39855 rows x 3 columns]

# %%
g_par_try = pd.merge(new_par_try, meta_genre_with_keyowrd[['album_id', 'genre_mid']], on = 'album_id', how = 'left')
g_par_try
# Out:
#        album_id   sub_title pr_int genre_mid
# 0           749    꼬마버스 타요1    P05      TV만화
# 1           750    꼬마버스 타요1    P05      TV만화
# 2          2131    꼬마버스 타요1    P05      TV만화
# 3          2625    꼬마버스 타요1    P05      TV만화
# 4          2594    꼬마버스 타요1    P05      TV만화
# ...         ...         ...    ...       ...
# 39870     39872  로티프렌즈 미술놀이    nan      놀이교실
# 39871     39873  로티프렌즈 미술놀이    nan      놀이교실
# 39872     39874  로티프렌즈 미술놀이    nan      놀이교실
# 39873      4779        4-5세    P01         책
# 39874     11629  베이비 타요 동요2    nan      노래율동
#
# [39875 rows x 4 columns]

# %%
for i in g_par_try[0:2].itertuples():
    print(i)
# Out:
# Pandas(Index=0, album_id=749, sub_title='꼬마버스 타요1', pr_int='P05', genre_mid='TV만화')
# Pandas(Index=1, album_id=750, sub_title='꼬마버스 타요1', pr_int='P05', genre_mid='TV만화')

# %%
genre_cnt = 0
execption = 0
for i in g_par_try.itertuples():
    if i[3] == 'nan':
        genre_cnt += 1
        if i[4] in pr_genre_dict['pr_int'].keys():
            g_par_try.loc[i[0], 'pr_int'] = pr_genre_dict['pr_int'][i[4]]
        else:
            g_par_try.loc[i[0], 'pr_int'] = 'P02'
            print(i)
            execption += 1
# Out:
# Pandas(Index=14296, album_id=32755, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14297, album_id=32756, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14298, album_id=32757, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14299, album_id=32758, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14300, album_id=32759, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14301, album_id=32760, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14302, album_id=32761, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14303, album_id=32762, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14304, album_id=32763, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14305, album_id=32764, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14306, album_id=32765, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14307, album_id=32766, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14723, album_id=33008, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14724, album_id=33009, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14728, album_id=33010, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14729, album_id=33011, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14730, album_id=33012, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14731, album_id=33013, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')
# Pandas(Index=14732, album_id=33014, sub_title='교육상식', pr_int='nan', genre_mid='휴먼/감동')

# %%
pr_key_max = g_par_try[['album_id', 'pr_int']]

# %%
pr_key_max
# Out:
#        album_id pr_int
# 0           749    P05
# 1           750    P05
# 2          2131    P05
# 3          2625    P05
# 4          2594    P05
# ...         ...    ...
# 39870     39872    P04
# 39871     39873    P04
# 39872     39874    P04
# 39873      4779    P01
# 39874     11629    P05
#
# [39875 rows x 2 columns]

# %%
import pickle
with open('pr_key_for_all_item.pickle', 'wb') as f:
    pickle.dump(pr_key_max, f)

# %%
genre_cnt
# Out:
# 4747

# %%
pr_genre_dict['pr_int'].keys()
# Out:
# dict_keys(['MCN', 'TV만화', '극장판 애니', '노래 율동', '노래율동', '놀이교실', '다큐멘터리', '독서동화', '드라마', '수학과학', '시리즈', '시사교양', '애니', '액션/모험', '어린이방송', '역사/문화', '연예오락', '예능', '예술', '외국어', '유아애니', '육아정보', '창의학습', '책', '체육안전', '코미디', '한글', '한자'])

# %%
meta_df.genre_mid.value_counts()
# 29개
# Out:
# 놀이교실      11084
# TV만화      10873
# 노래율동       7555
# 외국어        3342
# 애니         2110
# 예능         1719
# 책          1352
# 창의학습        799
# 액션/모험       701
# 유아애니        537
# 드라마         455
# 시리즈         390
# 독서동화        350
# 육아정보        308
# 시사교양        212
# 노래 율동       166
# MCN          93
# 코미디          80
# 어린이방송        79
# 다큐멘터리        72
# 연예오락         62
# 수학과학         60
# 한글           60
# 역사/문화        38
# 한자           38
# 예술           21
# 휴먼/감동        20
# 극장판 애니       13
# 체육안전         13
# Name: genre_mid, dtype: int64

# %%
execption
# Out:
# 19

# %%
g_par_try
# Out:
#        album_id   sub_title pr_int genre_mid
# 0           749    꼬마버스 타요1    P05      TV만화
# 1           750    꼬마버스 타요1    P05      TV만화
# 2          2131    꼬마버스 타요1    P05      TV만화
# 3          2625    꼬마버스 타요1    P05      TV만화
# 4          2594    꼬마버스 타요1    P05      TV만화
# ...         ...         ...    ...       ...
# 39870     39872  로티프렌즈 미술놀이    P04      놀이교실
# 39871     39873  로티프렌즈 미술놀이    P04      놀이교실
# 39872     39874  로티프렌즈 미술놀이    P04      놀이교실
# 39873      4779        4-5세    P01         책
# 39874     11629  베이비 타요 동요2    P05      노래율동
#
# [39875 rows x 4 columns]

# %%
genre_cnt
# Out:
# 4728

# %%
g_par_try.loc[g_par_try['pr_int'] == 'nan']
# Out:
# Empty DataFrame
# Columns: [album_id, sub_title, pr_int, genre_mid]
# Index: []
